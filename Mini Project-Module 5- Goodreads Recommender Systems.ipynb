# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv("books.csv", error_bad_lines = False)
df
# Out:
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#              isbn         isbn13 language_code    num_pages  ratings_count  \
# 0      0439785960  9780439785969           eng          652        2095690
# 1      0439358078  9780439358071           eng          870        2153167
# 2      0439554896  9780439554893           eng          352           6333
# 3      043965548X  9780439655484           eng          435        2339585
# 4      0439682584  9780439682589           eng         2690          41428
# ...           ...            ...           ...          ...            ...
# 11118  1560254416  9781560254416           eng          512            156
# 11119  0140110879  9780140110876           eng          635            783
# 11120  0140131965  9780140131963           eng          415            820
# 11121  0060878827  9780060878825           eng          434            769
# 11122  8497646983  9788497646987           spa          272            113
#
#        text_reviews_count publication_date        publisher
# 0                   27591        9/16/2006  Scholastic Inc.
# 1                   29221         9/1/2004  Scholastic Inc.
# 2                     244        11/1/2003       Scholastic
# 3                   36325         5/1/2004  Scholastic Inc.
# 4                     164        9/13/2004       Scholastic
# ...                   ...              ...              ...
# 11118                  20       12/21/2004    Da Capo Press
# 11119                  56        12/1/1988    Penguin Books
# 11120                  95         8/1/1993    Penguin Books
# 11121                 139        2/27/2007             Ecco
# 11122                  12        5/28/2006    Edimat Libros
#
# [11123 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16, 4))
ax = sns.countplot(x=df.language_code, data=df)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x()-0.05, p.get_height()+100))

# %%
df = df.loc[df['language_code'].isin(['eng','eng-US','en-GB','en-CA'])].reset_index()
df
# Out:
#       index  bookID                                              title  \
# 0         0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1         1       2  Harry Potter and the Order of the Phoenix (Har...
# 2         2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3         3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4         4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...     ...     ...                                                ...
# 9124  11103   45572                 Fantastic Mr. Fox (Cover to Cover)
# 9125  11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 9126  11119   45633                        You Bright and Risen Angels
# 9127  11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 9128  11121   45639                                        Poor People
#
#                                                 authors  average_rating  \
# 0                            J.K. Rowling/Mary GrandPré            4.57
# 1                            J.K. Rowling/Mary GrandPré            4.49
# 2                                          J.K. Rowling            4.42
# 3                            J.K. Rowling/Mary GrandPré            4.56
# 4                            J.K. Rowling/Mary GrandPré            4.78
# ...                                                 ...             ...
# 9124                                         Roald Dahl            4.05
# 9125  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 9126                                William T. Vollmann            4.08
# 9127                                William T. Vollmann            3.96
# 9128                                William T. Vollmann            3.72
#
#             isbn         isbn13 language_code    num_pages  ratings_count  \
# 0     0439785960  9780439785969           eng          652        2095690
# 1     0439358078  9780439358071           eng          870        2153167
# 2     0439554896  9780439554893           eng          352           6333
# 3     043965548X  9780439655484           eng          435        2339585
# 4     0439682584  9780439682589           eng         2690          41428
# ...          ...            ...           ...          ...            ...
# 9124  1855495090  9781855495098           eng           90              7
# 9125  1560254416  9781560254416           eng          512            156
# 9126  0140110879  9780140110876           eng          635            783
# 9127  0140131965  9780140131963           eng          415            820
# 9128  0060878827  9780060878825           eng          434            769
#
#       text_reviews_count publication_date        publisher
# 0                  27591        9/16/2006  Scholastic Inc.
# 1                  29221         9/1/2004  Scholastic Inc.
# 2                    244        11/1/2003       Scholastic
# 3                  36325         5/1/2004  Scholastic Inc.
# 4                    164        9/13/2004       Scholastic
# ...                  ...              ...              ...
# 9124                   0        9/15/1995   BBC Audiobooks
# 9125                  20       12/21/2004    Da Capo Press
# 9126                  56        12/1/1988    Penguin Books
# 9127                  95         8/1/1993    Penguin Books
# 9128                 139        2/27/2007             Ecco
#
# [9129 rows x 13 columns]

# %%
plt.figure(figsize=(16, 4))
ax = sns.countplot(x=df.language_code, data=df)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x()-0.05, p.get_height()+100))

# %%
#!.[alt text].(IMDB.png "IMDB Calculation")
# Out:
# '.[alt' is not recognized as an internal or external command,
# operable program or batch file.

# %%
def popularityRecommender(df):
    
    minimum_rating_count = 0.75*df['ratings_count'].max()
    
    mean_rating =df['average_rating'].mean()
    
    df['weighted_rating'] = (((df['ratings_count']/(df['ratings_count']+minimum_rating_count)) * df['average_rating']) +
                             ((minimum_rating_count/(df['ratings_count']+minimum_rating_count))*mean_rating))


    recommendations = df.sort_values(by = 'weighted_rating',ascending = False).head(5)
    
    return(recommendations)

# %%
top5 = popularityRecommender(df)
top5.head(5)
# Out:
#       index  bookID                                              title  \
# 3         3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 0         0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1         1       2  Harry Potter and the Order of the Phoenix (Har...
# 3658   4415   15881  Harry Potter and the Chamber of Secrets (Harry...
# 22       23      34  The Fellowship of the Ring (The Lord of the Ri...
#
#                          authors  average_rating        isbn         isbn13  \
# 3     J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 0     J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1     J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 3658  J.K. Rowling/Mary GrandPré            4.42  0439064864  9780439064866
# 22                J.R.R. Tolkien            4.36  0618346252  9780618346257
#
#      language_code    num_pages  ratings_count  text_reviews_count  \
# 3              eng          435        2339585               36325
# 0              eng          652        2095690               27591
# 1              eng          870        2153167               29221
# 3658           eng          341        2293963               34692
# 22             eng          398        2128944               13670
#
#      publication_date                                 publisher  \
# 3            5/1/2004                           Scholastic Inc.
# 0           9/16/2006                           Scholastic Inc.
# 1            9/1/2004                           Scholastic Inc.
# 3658         6/2/1999  Arthur A. Levine Books / Scholastic Inc.
# 22           9/5/2003                 Houghton Mifflin Harcourt
#
#       weighted_rating
# 3            4.186974
# 0            4.174344
# 1            4.147652
# 3658         4.128082
# 22           4.096541

# %%
top5Names = df["title"].head(5).values
print(top5Names)
# Out:
# ['Harry Potter and the Half-Blood Prince (Harry Potter  #6)'
#  'Harry Potter and the Order of the Phoenix (Harry Potter  #5)'
#  'Harry Potter and the Chamber of Secrets (Harry Potter  #2)'
#  'Harry Potter and the Prisoner of Azkaban (Harry Potter  #3)'
#  'Harry Potter Boxed Set  Books 1-5 (Harry Potter  #1-5)']

# %%
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer

cbr = TfidfVectorizer(stop_words='english')

tfidf_matrix = cbr.fit_transform(df['title'])
    
distance_matrix = linear_kernel(tfidf_matrix)

indices = pd.Series(df.index, index=df['title']).drop_duplicates()

# %%
distance_matrix.size
# Out:
# 83338641

# %%
def ContentBasedRecommender(title, indices, distance_matrix):
    id_ = indices[title]
    distances = list(enumerate(distance_matrix[id_]))
    distances = sorted(distances, key=lambda x: x[1], reverse = True)
    distances = distances[1:6]
    recommendations = [distance[0] for distance in distances]
    return df['title'].iloc[recommendations]

# %%
ContentBasedRecommender("Poor People", indices,distance_matrix)
# Out:
# 6353                  The Book of Other People
# 7842                       A Man of the People
# 2873                            All New People
# 2523    The Working Poor: Invisible in America
# 184              We Were Not Like Other People
# Name: title, dtype: object

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cbr = TfidfVectorizer(stop_words='english')

tfidf_matrix = cbr.fit_transform(df['authors'])
    
distance_matrix = cosine_similarity(tfidf_matrix)

df= df.drop_duplicates(subset = "authors")
indices = pd.Series(df.index, index=df['authors']).drop_duplicates(keep = "first", inplace = False)

# %%
indices
# Out:
# authors
# J.K. Rowling/Mary GrandPré                                   0
# J.K. Rowling                                                 2
# Douglas Adams                                                6
# Douglas Adams/Stephen Fry                                    9
# Bill Bryson                                                 11
#                                                           ...
# Sam R. Watkins                                            9121
# Alexander Hunter                                          9122
# David Wood/Roald Dahl                                     9123
# William T. Vollmann/Larry McCaffery/Michael Hemmingson    9125
# William T. Vollmann                                       9126
# Length: 5611, dtype: int64

# %%
def ContentBasedAuthorRecommender(author, indices, distance_matrix):
    id_ = indices[author]
    distances = list(enumerate(distance_matrix[id_]))
    distances = sorted(distances, key=lambda x: x[1], reverse = True)
    distances = distances[1:6]
    recommendations = [distance[0] for distance in distances]
    return df['authors'].iloc[recommendations]

# %%
ContentBasedAuthorRecommender("J.K. Rowling", indices, distance_matrix)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    1484         try:
# -> 1485             return self.obj._take_with_is_copy(key, axis=axis)
#    1486         except IndexError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _take_with_is_copy(self, indices, axis)
#     921         """
# --> 922         return self.take(indices=indices, axis=axis)
#     923
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in take(self, indices, axis, is_copy, **kwargs)
#     906         indices = ensure_platform_int(indices)
# --> 907         new_index = self.index.take(indices)
#     908         new_values = self._values.take(indices)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1120         if isinstance(values, np.ndarray):
# -> 1121             taken = algos.take(
#    1122                 values, indices, allow_fill=allow_fill, fill_value=self._na_value
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in take(arr, indices, axis, allow_fill, fill_value)
#    1448         # NumPy style
# -> 1449         result = arr.take(indices, axis=axis)
#    1450     return result
#
# IndexError: index 8794 is out of bounds for axis 0 with size 5611
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11108\880167579.py in <module>
# ----> 1 ContentBasedAuthorRecommender("J.K. Rowling", indices, distance_matrix)
#
# ~\AppData\Local\Temp\ipykernel_11108\3595209074.py in ContentBasedAuthorRecommender(author, indices, distance_matrix)
#       5     distances = distances[1:6]
#       6     recommendations = [distance[0] for distance in distances]
# ----> 7     return df['authors'].iloc[recommendations]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1512         # a list of integers
#    1513         elif is_list_like_indexer(key):
# -> 1514             return self._get_list_axis(key, axis=axis)
#    1515
#    1516         # a single integer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    1486         except IndexError as err:
#    1487             # re-raise with different error message
# -> 1488             raise IndexError("positional indexers are out-of-bounds") from err
#    1489
#    1490     def _getitem_axis(self, key, axis: int):
#
# IndexError: positional indexers are out-of-bounds
