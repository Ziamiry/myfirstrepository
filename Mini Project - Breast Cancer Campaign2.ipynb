# %%
import pandas as pd
import numpy as np
df = pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df = df.dropna()
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

df["sex"] = LabelEncoder().fit_transform(df[["sex"]])
# Out:
# C:\Users\smiry\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    0  27.900         0    yes  southwest  16884.92400
# 1      18    1  33.770         1     no  southeast   1725.55230
# 2      28    1  33.000         3     no  southeast   4449.46200
# 3      33    1  22.705         0     no  northwest  21984.47061
# 4      32    1  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    1  30.970         3     no  northwest  10600.54830
# 1334   18    0  31.920         0     no  northeast   2205.98080
# 1335   18    0  36.850         0     no  southeast   1629.83350
# 1336   21    0  25.800         0     no  southwest   2007.94500
# 1337   61    0  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df["smoker"] = LabelEncoder().fit_transform(df[["smoker"]])
# Out:
# C:\Users\smiry\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df["region"] = LabelEncoder().fit_transform(df[["region"]])
# Out:
# C:\Users\smiry\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

df_scaled = scaler.fit_transform(df.to_numpy())

df_scaled = pd.DataFrame(df_scaled, columns= ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'])

df_scaled
# Out:
#            age       sex       bmi  children    smoker    region   charges
# 0    -1.438764 -1.010519 -0.453320 -0.908614  1.970587  1.343905  0.298584
# 1    -1.509965  0.989591  0.509621 -0.078767 -0.507463  0.438495 -0.953689
# 2    -0.797954  0.989591  0.383307  1.580926 -0.507463  0.438495 -0.728675
# 3    -0.441948  0.989591 -1.305531 -0.908614 -0.507463 -0.466915  0.719843
# 4    -0.513149  0.989591 -0.292556 -0.908614 -0.507463 -0.466915 -0.776802
# ...        ...       ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926 -0.507463 -0.466915 -0.220551
# 1334 -1.509965 -1.010519  0.206139 -0.908614 -0.507463 -1.372326 -0.914002
# 1335 -1.509965 -1.010519  1.014878 -0.908614 -0.507463  0.438495 -0.961596
# 1336 -1.296362 -1.010519 -0.797813 -0.908614 -0.507463  1.343905 -0.930362
# 1337  1.551686 -1.010519 -0.261388 -0.908614  1.970587 -0.466915  1.311053
#
# [1338 rows x 7 columns]

# %%
X = df_scaled.iloc[:, 0:6]
y= df.iloc[:, 6:7]

# %%
X
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.438764 -1.010519 -0.453320 -0.908614  1.970587  1.343905
# 1    -1.509965  0.989591  0.509621 -0.078767 -0.507463  0.438495
# 2    -0.797954  0.989591  0.383307  1.580926 -0.507463  0.438495
# 3    -0.441948  0.989591 -1.305531 -0.908614 -0.507463 -0.466915
# 4    -0.513149  0.989591 -0.292556 -0.908614 -0.507463 -0.466915
# ...        ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926 -0.507463 -0.466915
# 1334 -1.509965 -1.010519  0.206139 -0.908614 -0.507463 -1.372326
# 1335 -1.509965 -1.010519  1.014878 -0.908614 -0.507463  0.438495
# 1336 -1.296362 -1.010519 -0.797813 -0.908614 -0.507463  1.343905
# 1337  1.551686 -1.010519 -0.261388 -0.908614  1.970587 -0.466915
#
# [1338 rows x 6 columns]

# %%
y
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
sns.pairplot(df_scaled)

# %%
corr = df_scaled.corr()

sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_validate, X_test, y_validate, y_test = train_test_split(X, y, test_size=0.5)

# %%
from sklearn.ensemble import RandomForestRegressor

modelLR = RandomForestRegressor(criterion = "mse").fit(X_train, y_train)
score = modelLR.score(X_test, y_test)
y_pred = modelLR.predict(X_test)
print(score)
# Out:
# C:\Users\smiry\AppData\Local\Temp\ipykernel_20372\110372213.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   modelLR = RandomForestRegressor(criterion = "mse").fit(X_train, y_train)
# C:\Users\smiry\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# 0.9437290459426666

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0).fit(X_train, y_train)
score = regressor.score(X_test, y_test)
y_pred = regressor.predict(X_test)
print(score)
# Out:
# 0.9323114513400825

# %%
from sklearn.svm import SVR
regressor2 = SVR(kernel='rbf').fit(X_train, y_train)
score2 = regressor.score(X_test, y_test)
y_pred = regressor2.predict(X_test)
print(score)
# Out:
# 0.9323114513400825
# C:\Users\smiry\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
